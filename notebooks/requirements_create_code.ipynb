# %% [markdown]
# Creating a requirement.txt file to run at the begigging of the project

# %%
# Manual clean write
requirements_content = """
pandas
numpy
scikit-learn
xgboost
shap
matplotlib
seaborn
joblib
"""

with open('requirements.txt', 'w') as f:
    f.write(requirements_content.strip())

print("✅ requirements.txt now contains only the essential project libraries.")
# Out:
# ✅ requirements.txt now contains only the essential project libraries.
